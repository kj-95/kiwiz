# %%
#import libraries
import pandas as pd

# %%
#load & read the file
df = pd.read_csv('D:/bigmart sales/train_v9rqX0R.csv')

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
print(df.shape) #dimension of data: 8523 rows, 12 columns
print(df.dtypes) #datatypes: measures(4) and categorical variables
print(df["Item_Type"].unique()) #to get unique entries
print(len(df["Item_Type"].unique())) #16 categories of products available
print(len(df["Item_Identifier"].unique())) #1559 unique products types
print(len(df["Outlet_Identifier"].unique())) #10 outlets
print(df["Outlet_Establishment_Year"].unique()) # 1985-2009
print(len(df["Outlet_Establishment_Year"].unique()))
# Out:
# (8523, 12)
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object
# ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
# 16
# 1559
# 10
# [1999 2009 1998 1987 1985 2002 2007 1997 2004]
# 9

# %%
#to find null values in data
df.isna().sum() #found in size of store no: 10,17,45 and item weight in store no:19,27
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# data prepration & cleaning

# %%
df['Item_Weight'].fillna(min(df["Item_Weight"]), inplace = True)  
df['Outlet_Size'].fillna("NA", inplace = True)  
df['Item_Fat_Content'].replace(to_replace="LF", value="Low Fat",inplace = True)
df['Item_Fat_Content'].replace(to_replace="low fat", value="Low Fat",inplace = True)
df['Item_Fat_Content'].replace(to_replace="reg", value="Regular",inplace = True)

#print(df.iloc[7])
#print(df.iloc[3])
#print(df.iloc[65])
#print(df.iloc[81])

# %% [markdown]
# df.dropna(inplace=True) #deletes row which has atleast 1 na
# print(df.shape)

# %%
#checking null presence after making changes
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# data visualisation

# %%
#import libraries


import matplotlib.pyplot as plt
import seaborn as sns

# %%
#types of store
#sns.catplot(y=df["Outlet_Identifier"],x=df["Outlet_Type"], palette="pastel", data=df)
sns.countplot(y=df["Outlet_Type"], data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Outlet_Type'>

# %%
sns.countplot(y=df["Outlet_Identifier"], data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Outlet_Identifier'>

# %% [markdown]
# Shows 10 store outlets are distributed among 4 types of store. Maximum number of stores are of Supermarket-1 type

# %%
#distribution of store across location
#sns.stripplot(y=df["Outlet_Identifier"],x=df["Outlet_Location_Type"], palette="pastel", data=df)
sns.countplot(y=df["Outlet_Location_Type"], data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Outlet_Location_Type'>

# %%
#Store types,size,location,establishment year, outlet no, sales

year_sale_dx = df.groupby(by=['Outlet_Type', 'Outlet_Identifier','Outlet_Establishment_Year','Outlet_Location_Type','Outlet_Size'])['Item_Outlet_Sales'].sum().reset_index()
#year_sale = year_sale_dx.groupby(by=['Item_Type'])['Item_Outlet_Sales'].transform(min) == year_sale_dx['Item_Outlet_Sales']
#year_sale_min = year_sale_dx[year_sale].reset_index(drop=True)
year_sale_dx.sort_values(by='Item_Outlet_Sales')
# Out:
#          Outlet_Type Outlet_Identifier  Outlet_Establishment_Year  \
# 0      Grocery Store            OUT019                       1985
# 5  Supermarket Type2            OUT018                       2009
# 3  Supermarket Type1            OUT046                       1997
# 1  Supermarket Type1            OUT013                       1987
# 4  Supermarket Type1            OUT049                       1999
# 2  Supermarket Type1            OUT035                       2004
# 6  Supermarket Type3            OUT027                       1985
#
#   Outlet_Location_Type Outlet_Size  Item_Outlet_Sales
# 0               Tier 1       Small       1.796941e+05
# 5               Tier 3      Medium       1.851823e+06
# 3               Tier 1       Small       2.118395e+06
# 1               Tier 3        High       2.142664e+06
# 4               Tier 1      Medium       2.183970e+06
# 2               Tier 2       Small       2.268123e+06
# 6               Tier 3      Medium       3.453926e+06

# %%
#Analysis of sales of item types in Grocery store
year_sale_dx = df.groupby(by=['Outlet_Type', 'Item_Type'])['Item_Outlet_Sales'].sum().reset_index()
year_sale = year_sale_dx.groupby(by=['Item_Type'])['Item_Outlet_Sales'].transform(min) == year_sale_dx['Item_Outlet_Sales']
year_sale_min = year_sale_dx[year_sale].reset_index(drop=True)
year_sale_min.sort_values(by='Item_Outlet_Sales')
# Out:
#       Outlet_Type              Item_Type  Item_Outlet_Sales
# 12  Grocery Store                Seafood          2284.3598
# 15  Grocery Store          Starchy Foods          3901.5880
# 7   Grocery Store            Hard Drinks          5835.7370
# 11  Grocery Store                 Others          7778.5414
# 2   Grocery Store              Breakfast          7843.7898
# 1   Grocery Store                 Breads         12604.9256
# 14  Grocery Store            Soft Drinks         18554.5144
# 8   Grocery Store     Health and Hygiene         24515.4218
# 0   Grocery Store           Baking Goods         24827.0162
# 10  Grocery Store                   Meat         25576.7070
# 3   Grocery Store                 Canned         25759.1362
# 4   Grocery Store                  Dairy         31451.7262
# 5   Grocery Store           Frozen Foods         33195.4564
# 9   Grocery Store              Household         43707.1068
# 6   Grocery Store  Fruits and Vegetables         48602.0684
# 13  Grocery Store            Snack Foods         51596.1710

# %%
#count of product items of each category in Grocery store
year_sale_dx = df.groupby(by=['Outlet_Type','Item_Type'])['Item_Identifier'].count().reset_index()
year_sale_dx.head(17)
# Out:
#           Outlet_Type              Item_Type  Item_Identifier
# 0       Grocery Store           Baking Goods               85
# 1       Grocery Store                 Breads               33
# 2       Grocery Store              Breakfast               19
# 3       Grocery Store                 Canned               73
# 4       Grocery Store                  Dairy               92
# 5       Grocery Store           Frozen Foods              103
# 6       Grocery Store  Fruits and Vegetables              152
# 7       Grocery Store            Hard Drinks               24
# 8       Grocery Store     Health and Hygiene               67
# 9       Grocery Store              Household              119
# 10      Grocery Store                   Meat               66
# 11      Grocery Store                 Others               27
# 12      Grocery Store                Seafood               10
# 13      Grocery Store            Snack Foods              146
# 14      Grocery Store            Soft Drinks               54
# 15      Grocery Store          Starchy Foods               13
# 16  Supermarket Type1           Baking Goods              426

# %%
#count of product items of each category in Outlet 27 (comparison with highest revenue store)
year_sale_dx = df.groupby(by=['Outlet_Type','Item_Type'])['Item_Identifier'].count().reset_index()
year_sale_dx.tail(17)
# Out:
#           Outlet_Type              Item_Type  Item_Identifier
# 47  Supermarket Type2          Starchy Foods               17
# 48  Supermarket Type3           Baking Goods               69
# 49  Supermarket Type3                 Breads               31
# 50  Supermarket Type3              Breakfast               11
# 51  Supermarket Type3                 Canned               72
# 52  Supermarket Type3                  Dairy               67
# 53  Supermarket Type3           Frozen Foods               89
# 54  Supermarket Type3  Fruits and Vegetables              140
# 55  Supermarket Type3            Hard Drinks               23
# 56  Supermarket Type3     Health and Hygiene               60
# 57  Supermarket Type3              Household               99
# 58  Supermarket Type3                   Meat               56
# 59  Supermarket Type3                 Others               15
# 60  Supermarket Type3                Seafood                7
# 61  Supermarket Type3            Snack Foods              137
# 62  Supermarket Type3            Soft Drinks               45
# 63  Supermarket Type3          Starchy Foods               14

# %%
#Visibility of item types in Grocery store
year_sale_dx = df.groupby(by=['Outlet_Type','Outlet_Identifier','Item_Type'])['Item_Visibility'].mean().reset_index()
year_sale_dx.head(33)
# Out:
#           Outlet_Type Outlet_Identifier              Item_Type  \
# 0       Grocery Store            OUT010           Baking Goods
# 1       Grocery Store            OUT010                 Breads
# 2       Grocery Store            OUT010              Breakfast
# 3       Grocery Store            OUT010                 Canned
# 4       Grocery Store            OUT010                  Dairy
# 5       Grocery Store            OUT010           Frozen Foods
# 6       Grocery Store            OUT010  Fruits and Vegetables
# 7       Grocery Store            OUT010            Hard Drinks
# 8       Grocery Store            OUT010     Health and Hygiene
# 9       Grocery Store            OUT010              Household
# 10      Grocery Store            OUT010                   Meat
# 11      Grocery Store            OUT010                 Others
# 12      Grocery Store            OUT010                Seafood
# 13      Grocery Store            OUT010            Snack Foods
# 14      Grocery Store            OUT010            Soft Drinks
# 15      Grocery Store            OUT010          Starchy Foods
# 16      Grocery Store            OUT019           Baking Goods
# 17      Grocery Store            OUT019                 Breads
# 18      Grocery Store            OUT019              Breakfast
# 19      Grocery Store            OUT019                 Canned
# 20      Grocery Store            OUT019                  Dairy
# 21      Grocery Store            OUT019           Frozen Foods
# 22      Grocery Store            OUT019  Fruits and Vegetables
# 23      Grocery Store            OUT019            Hard Drinks
# 24      Grocery Store            OUT019     Health and Hygiene
# 25      Grocery Store            OUT019              Household
# 26      Grocery Store            OUT019                   Meat
# 27      Grocery Store            OUT019                 Others
# 28      Grocery Store            OUT019                Seafood
# 29      Grocery Store            OUT019            Snack Foods
# 30      Grocery Store            OUT019            Soft Drinks
# 31      Grocery Store            OUT019          Starchy Foods
# 32  Supermarket Type1            OUT013           Baking Goods
#
#     Item_Visibility
# 0          0.128830
# 1          0.098883
# 2          0.114933
# 3          0.102539
# 4          0.115688
# 5          0.095684
# 6          0.101924
# 7          0.103827
# 8          0.089080
# 9          0.093731
# 10         0.088586
# 11         0.100400
# 12         0.089788
# 13         0.095043
# 14         0.095271
# 15         0.152473
# 16         0.114375
# 17         0.109282
# 18         0.147833
# 19         0.095495
# 20         0.121784
# 21         0.102066
# 22         0.118954
# 23         0.100056
# 24         0.087054
# 25         0.106460
# 26         0.091965
# 27         0.080201
# 28         0.124030
# 29         0.113800
# 30         0.112528
# 31         0.092947
# 32         0.059490

# %%
#Visibility of item types in Grocery store
year_sale_dx = df.groupby(by=['Outlet_Type','Item_Type'])['Item_Visibility'].mean().reset_index()
year_sale_dx.tail(17)
# Out:
#           Outlet_Type              Item_Type  Item_Visibility
# 47  Supermarket Type2          Starchy Foods         0.054944
# 48  Supermarket Type3           Baking Goods         0.059348
# 49  Supermarket Type3                 Breads         0.053400
# 50  Supermarket Type3              Breakfast         0.065450
# 51  Supermarket Type3                 Canned         0.059777
# 52  Supermarket Type3                  Dairy         0.063534
# 53  Supermarket Type3           Frozen Foods         0.059233
# 54  Supermarket Type3  Fruits and Vegetables         0.060610
# 55  Supermarket Type3            Hard Drinks         0.052369
# 56  Supermarket Type3     Health and Hygiene         0.048012
# 57  Supermarket Type3              Household         0.054549
# 58  Supermarket Type3                   Meat         0.063281
# 59  Supermarket Type3                 Others         0.070487
# 60  Supermarket Type3                Seafood         0.071265
# 61  Supermarket Type3            Snack Foods         0.059174
# 62  Supermarket Type3            Soft Drinks         0.058214
# 63  Supermarket Type3          Starchy Foods         0.050326

# %%
#Correlation analysis between variables
df['Item_Visibility'].replace(to_replace="NA", value=min(df["Item_Visibility"]),inplace = True)
corr = df.corr()
ax = sns.heatmap(corr, vmin=-1, vmax=1, center=0)

# %%
#mean price of products under each item category in Grocery store
year_sale_dx = df.groupby(by=['Outlet_Type','Item_Type'])['Item_MRP'].mean().reset_index()
year_sale_dx.head(17)
# Out:
#           Outlet_Type              Item_Type    Item_MRP
# 0       Grocery Store           Baking Goods  126.438068
# 1       Grocery Store                 Breads  146.452873
# 2       Grocery Store              Breakfast  147.026989
# 3       Grocery Store                 Canned  138.080808
# 4       Grocery Store                  Dairy  147.166715
# 5       Grocery Store           Frozen Foods  133.499427
# 6       Grocery Store  Fruits and Vegetables  140.943517
# 7       Grocery Store            Hard Drinks  117.189350
# 8       Grocery Store     Health and Hygiene  133.791394
# 9       Grocery Store              Household  151.950499
# 10      Grocery Store                   Meat  137.591648
# 11      Grocery Store                 Others  128.417230
# 12      Grocery Store                Seafood  143.816220
# 13      Grocery Store            Snack Foods  146.081097
# 14      Grocery Store            Soft Drinks  142.099422
# 15      Grocery Store          Starchy Foods  148.153754
# 16  Supermarket Type1           Baking Goods  125.975262

# %%
#mean price of products under each item category in Grocery store
year_sale_dx = df.groupby(by=['Outlet_Type','Item_Type'])['Item_MRP'].mean().reset_index()
year_sale_dx.tail(17)
# Out:
#           Outlet_Type              Item_Type    Item_MRP
# 47  Supermarket Type2          Starchy Foods  151.786918
# 48  Supermarket Type3           Baking Goods  128.809243
# 49  Supermarket Type3                 Breads  145.676239
# 50  Supermarket Type3              Breakfast  147.083909
# 51  Supermarket Type3                 Canned  140.625689
# 52  Supermarket Type3                  Dairy  148.037063
# 53  Supermarket Type3           Frozen Foods  137.149955
# 54  Supermarket Type3  Fruits and Vegetables  145.009904
# 55  Supermarket Type3            Hard Drinks  143.576530
# 56  Supermarket Type3     Health and Hygiene  127.852417
# 57  Supermarket Type3              Household  146.528871
# 58  Supermarket Type3                   Meat  139.877168
# 59  Supermarket Type3                 Others  106.779053
# 60  Supermarket Type3                Seafood  124.028286
# 61  Supermarket Type3            Snack Foods  144.574508
# 62  Supermarket Type3            Soft Drinks  123.313587
# 63  Supermarket Type3          Starchy Foods  143.078386

# %%
# patterns of sales in bigmart
#analysis of count and sales under each product category across stores
fig, axes = plt.subplots(3, 1, figsize=(10, 10))
sns.countplot(ax=axes[0],y=df["Item_Type"],palette="pastel", data=df)
sns.barplot(ax=axes[1],y=df["Item_Type"],x=df["Item_Outlet_Sales"], palette="pastel", data=df)
sns.barplot(ax=axes[2],y=df["Item_Type"],x=df["Item_MRP"], palette="pastel", data=df)
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Item_Type'>

# %%
#sales of fat content products
fig, axes = plt.subplots(3, 1, figsize=(10, 10))
sns.countplot(ax=axes[0],x=df["Item_Fat_Content"],palette="pastel", data=df)
sns.barplot(ax=axes[1],x=df["Item_Fat_Content"],y=df["Item_Outlet_Sales"], palette="pastel", data=df)
sns.barplot(ax=axes[2],x=df["Item_Fat_Content"],y=df["Item_MRP"], palette="pastel", data=df)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Item_MRP'>

# %%
#products having highest revenue across all stores
cg=df.groupby('Item_Identifier')
z=cg['Item_Outlet_Sales'].agg(['mean','sum']).sort_values(by='mean', ascending=False)
z.head(10)
# Out:
#                         mean         sum
# Item_Identifier
# FDR45            6035.310550  24141.2422
# NCL42            5962.017067  17886.0512
# FDU55            5922.457450  23689.8298
# FDZ50            5512.824000  11025.6480
# DRK23            5464.886400  27324.4320
# FDF39            5457.063250  21828.2530
# FDD44            5453.900700  32723.4042
# FDT16            5414.818240  27074.0912
# FDY55            5332.725100  42661.8008
# FDG17            5314.582050  21258.3282

# %%
#top porodcuts have high mean revenue
#under which item type does these products fall under: 

type=['FDR45','NCL42','FDU55','FDZ50','DRK23','FDF39','FDD44','FDT16','FDY55','FDG17']
filt=df['Item_Identifier'].isin(type)
df.loc[filt,['Item_Type','Item_Identifier']]
# Out:
#                   Item_Type Item_Identifier
# 276   Fruits and Vegetables           FDY55
# 332   Fruits and Vegetables           FDU55
# 366   Fruits and Vegetables           FDD44
# 670             Hard Drinks           DRK23
# 732             Hard Drinks           DRK23
# 1067  Fruits and Vegetables           FDD44
# 1255  Fruits and Vegetables           FDY55
# 1348           Frozen Foods           FDG17
# 1467                  Dairy           FDZ50
# 1541  Fruits and Vegetables           FDD44
# 1554           Frozen Foods           FDG17
# 1755  Fruits and Vegetables           FDU55
# 1790  Fruits and Vegetables           FDY55
# 1821            Snack Foods           FDR45
# 1835              Household           NCL42
# 2109  Fruits and Vegetables           FDU55
# 2216           Frozen Foods           FDT16
# 2293            Snack Foods           FDR45
# 2535  Fruits and Vegetables           FDD44
# 2995           Frozen Foods           FDT16
# 3062            Hard Drinks           DRK23
# 3087            Hard Drinks           DRK23
# 3496                  Dairy           FDF39
# 3709           Frozen Foods           FDG17
# 4306  Fruits and Vegetables           FDD44
# 4313            Snack Foods           FDR45
# 4346  Fruits and Vegetables           FDY55
# 4763                  Dairy           FDF39
# 4854  Fruits and Vegetables           FDD44
# 4873            Snack Foods           FDR45
# 4884              Household           NCL42
# 4888                  Dairy           FDF39
# 5365           Frozen Foods           FDT16
# 5474            Hard Drinks           DRK23
# 5829           Frozen Foods           FDG17
# 6155                  Dairy           FDF39
# 6227                  Dairy           FDZ50
# 6341  Fruits and Vegetables           FDY55
# 6787  Fruits and Vegetables           FDY55
# 7006           Frozen Foods           FDT16
# 7014  Fruits and Vegetables           FDY55
# 7451           Frozen Foods           FDT16
# 7732              Household           NCL42
# 8039  Fruits and Vegetables           FDY55
# 8245  Fruits and Vegetables           FDU55

# %%
#Top 10 product items showing in which store they have highest revenue

year_sale_dx = df.groupby(by=['Outlet_Identifier','Item_Type','Item_Identifier'])['Item_Outlet_Sales'].sum().reset_index()
z=year_sale_dx.sort_values(by='Item_Outlet_Sales',ascending=False)
z.head(10)
# Out:
#      Outlet_Identifier              Item_Type Item_Identifier  \
# 4451            OUT027              Household           NCE42
# 4281            OUT027  Fruits and Vegetables           FDQ19
# 4343            OUT027  Fruits and Vegetables           FDZ20
# 4684            OUT027            Snack Foods           FDP33
# 4006            OUT027                 Canned           FDI50
# 772             OUT013                  Dairy           FDF39
# 4096            OUT027                  Dairy           FDU14
# 4466            OUT027              Household           NCH18
# 7195            OUT046     Health and Hygiene           NCM05
# 4126            OUT027           Frozen Foods           FDC17
#
#       Item_Outlet_Sales
# 4451         13086.9648
# 4281         12117.5600
# 4343         11445.1020
# 4684         10993.6896
# 4006         10306.5840
# 772          10256.6490
# 4096         10236.6750
# 4466         10072.8882
# 7195          9779.9362
# 4126          9678.0688

# %%
#top products have sum of revenue in which store outlet


#Bottomost 10 products having lowest revenue across all stores
cg=df.groupby('Item_Identifier')
z=cg['Item_Outlet_Sales'].agg(['mean','sum']).sort_values(by='mean')
z.head(10)
# Out:
#                        mean        sum
# Item_Identifier
# NCR42            110.966667   332.9000
# FDQ60            120.509800   120.5098
# FDQ04            261.437467   784.3124
# FDX10            291.121050  1164.4842
# NCN29            311.061760  1555.3088
# NCL41            334.675467  2008.0528
# NCO06            345.217300  2071.3038
# FDF38            385.831100   771.6622
# FDT02            388.161400  1552.6456
# FDX38            393.088320  1965.4416

# %%
#bottom products having lowest sum of revenue


#under which item type does these products fall under: 

type=['NCR42','FDQ60','FDQ04','FDX10','NCN29','NCL41','NCO06','FDF38','FDT02','FDX38']
filt=df['Item_Identifier'].isin(type)
df.loc[filt,['Item_Type','Item_Identifier']]
# Out:
#                Item_Type Item_Identifier
# 38           Snack Foods           FDX10
# 255         Frozen Foods           FDQ04
# 719   Health and Hygiene           NCN29
# 780            Household           NCO06
# 1003           Household           NCO06
# 1447         Snack Foods           FDX10
# 2157  Health and Hygiene           NCL41
# 2330  Health and Hygiene           NCN29
# 2711           Household           NCO06
# 2714              Canned           FDF38
# 3053  Health and Hygiene           NCL41
# 3250               Dairy           FDX38
# 3301               Dairy           FDX38
# 3373           Household           NCR42
# 3408           Household           NCO06
# 3586           Household           NCR42
# 4235               Dairy           FDT02
# 4373  Health and Hygiene           NCN29
# 4670  Health and Hygiene           NCN29
# 4936               Dairy           FDT02
# 5022        Baking Goods           FDQ60
# 5025  Health and Hygiene           NCL41
# 5202         Snack Foods           FDX10
# 5368        Frozen Foods           FDQ04
# 5706        Frozen Foods           FDQ04
# 5955           Household           NCO06
# 6166              Canned           FDF38
# 6264  Health and Hygiene           NCL41
# 6291           Household           NCO06
# 6368               Dairy           FDX38
# 6550               Dairy           FDX38
# 6642  Health and Hygiene           NCN29
# 6950           Household           NCR42
# 7126         Snack Foods           FDX10
# 7152  Health and Hygiene           NCL41
# 7328               Dairy           FDT02
# 7681               Dairy           FDX38
# 7924  Health and Hygiene           NCL41
# 8103               Dairy           FDT02

# %%
#Bottomost 10 product items showing in which store they have lowest revenue

year_sale_dx = df.groupby(by=['Outlet_Identifier','Item_Type','Item_Identifier'])['Item_Outlet_Sales'].sum().reset_index()
z=year_sale_dx.sort_values(by='Item_Outlet_Sales')
z.head(10)
# Out:
#      Outlet_Identifier           Item_Type Item_Identifier  Item_Outlet_Sales
# 539             OUT010         Soft Drinks           DRK12            33.2900
# 384             OUT010           Household           NCR42            33.2900
# 3816            OUT019         Snack Foods           FDU21            33.9558
# 3633            OUT019  Health and Hygiene           NCL41            34.6216
# 45              OUT010              Breads           FDQ47            35.2874
# 186             OUT010        Frozen Foods           FDS40            36.6190
# 3531            OUT019        Frozen Foods           FDS40            36.6190
# 3361            OUT019        Baking Goods           FDQ36            37.2848
# 3622            OUT019         Hard Drinks           DRK35            37.9506
# 3410            OUT019              Canned           FDA13            37.9506
